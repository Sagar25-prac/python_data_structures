# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagar25-prac/python_data_structures/blob/main/Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
empty_dict = {}
print(empty_dict)
# Out:
# {}

# %%
permissions = ["Read","View","Write"]

default_permission = dict.fromkeys(permissions,True)

print(default_permission)
# Out:
# {'Read': True, 'View': True, 'Write': True}

# %%
print(default_permission["View"])
# Out:
# True

# %%
config ={"size":"20","Theme":"dark"}

res = config.get("resolution","[Missing]")
print("Resolution:",res)

lang = config.get("language","English")
print("Language:",lang)

Theme = config.get("Theme","Light")
print("Theme:",Theme)
# Out:
# Resolution: [Missing]
# Language: English
# Theme: dark

# %%
del config["size"]

# %%
print(config)
# Out:
# {'Theme': 'dark'}
